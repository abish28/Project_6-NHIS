# %% [markdown]
# # Project_6
# # **Sales Forecasting Across Multiple Retail Storess**

# %% [markdown]
# ## Problem Statement

# %% [raw]
# Rossmann Pharmaceuticals has given you a project on sales forecasting. The finance team wants to forecast sales in all their stores across several cities six weeks ahead of time. Managers in individual stores rely on their years of experience as well as their personal judgement to forecast sales.

# %% [markdown]
# ## Step 1: Pharmaceutical Sales prediction

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Upload the given dataset "train.csv":

# %%
train_data = pd.read_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\train.csv")

# %%
train_data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# 3                  0              1
# 4                  0              1
# ...              ...            ...
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1
#
# [1017209 rows x 9 columns]

# %%
# Check the first 5 rows
train_data.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# check the last 5 rows
train_data.tail(5)
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1

# %%
# Checking Data set dimension
train_data.shape
print("The no of rows are :",train_data.shape[0])
print("The no of columns are :",train_data.shape[1])
# Out:
# The no of rows are : 1017209
# The no of columns are : 9

# %%
# Check the columns
train_data.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
# Let us see the info of the data
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
# check the null values in data set
train_data.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
#check the unique value
train_data.nunique()
# Out:
# Store             1115
# DayOfWeek            7
# Date               942
# Sales            21734
# Customers         4086
# Open                 2
# Promo                2
# StateHoliday         5
# SchoolHoliday        2
# dtype: int64

# %%
# statistical summary
train_data.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# max    1.000000e+00   1.000000e+00

# %% [markdown]
# ## Checking Outliers on train_data:

# %%
plt.figure(figsize=(10, 6))  
train_data.boxplot(column='Customers')
plt.title('Outlier in Customers Column',color='red')
plt.ylabel('Customers',color='red')
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
train_data.boxplot(column='Sales')
plt.title('Outlier in Sales Column',color='red')
plt.ylabel('Sales',color='red')
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
train_data.boxplot(column='Open')
plt.title('Outlier in Open Column',color='red')
plt.ylabel('Open',color='red')
plt.show()

# %% [markdown]
# ## Removing Outliers from train_data:

# %%
def iqr_technique(DFcolumn):
  Q1 = np.percentile(DFcolumn, 25)
  Q3 = np.percentile(DFcolumn, 75)
  IQR = Q3 - Q1
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)                        

  return lower_range,upper_range

# %%
lower_bound,upper_bound = iqr_technique(train_data['Customers'])

train_data = train_data[(train_data.Customers>lower_bound) & (train_data.Customers<upper_bound)]

# %%
lower_bound,upper_bound = iqr_technique(train_data['Sales'])

train_data = train_data[(train_data.Sales>lower_bound) & (train_data.Sales<upper_bound)]

# %%
plt.figure(figsize=(10, 6))
train_data.boxplot(column='Sales')
plt.title('Outlier in Sales Column',color='red')
plt.ylabel('Sales',color='red')
plt.show()

# %% [markdown]
# # 2. Upload the given dataset "test.csv":

# %%
test_data = pd.read_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\test.csv")

# %%
test_data
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 41083              0
# 41084              0
# 41085              0
# 41086              0
# 41087              1
#
# [41088 rows x 8 columns]

# %%
test_data.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
test_data.tail()
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 41083              0
# 41084              0
# 41085              0
# 41086              0
# 41087              1

# %%
test_data.shape
# Out:
# (41088, 8)

# %%
test_data.columns
# Out:
# Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday'],
#       dtype='object')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
test_data.isnull().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
test_data = test_data.fillna({'Open':0})

# %%
test_data.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# # 3. Upload the given dataset "store.csv":

# %%
store_data = pd.read_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\store.csv")

# %%
store_data
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# ...                         ...                       ...     ...
# 1110                        6.0                    2014.0       1
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                 NaN              NaN               NaN
# 1                13.0           2010.0   Jan,Apr,Jul,Oct
# 2                14.0           2011.0   Jan,Apr,Jul,Oct
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 1110             31.0           2013.0   Jan,Apr,Jul,Oct
# 1111              NaN              NaN               NaN
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1115 rows x 10 columns]

# %%
store_data.head(5)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
store_data.tail(5)
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 1110                        6.0                    2014.0       1
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 1110             31.0           2013.0   Jan,Apr,Jul,Oct
# 1111              NaN              NaN               NaN
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec

# %%
store_data.shape
# Out:
# (1115, 10)

# %%
store_data.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store_data.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
# Filling numerical missing values with median
numerical_cols = store_data.select_dtypes(include=['float64', 'int64']).columns
store_data[numerical_cols] = store_data[numerical_cols].apply(lambda x: x.fillna(x.median()), axis=0)

# %%
# Filling categorical missing values with 'Unknown'
categorical_cols = store_data.select_dtypes(include=['object']).columns
store_data[categorical_cols] = store_data[categorical_cols].apply(lambda x: x.fillna('Unknown'))

# %%
store_data.isnull().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %% [markdown]
# ## Checking Outliers on store_data:

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
store_data.boxplot(column='CompetitionDistance')
plt.title('Outlier in CompetitionDistance Column',color='red')
plt.ylabel('CompetitionDistance',color='red')
plt.show()

# %% [markdown]
# ## Removing Outliers from store_data:

# %%
lower_bound,upper_bound = iqr_technique(store_data['CompetitionDistance'])

store_data = store_data[(store_data.CompetitionDistance>lower_bound) & (store_data.CompetitionDistance<upper_bound)]

# %%
plt.figure(figsize=(10, 6))  
store_data.boxplot(column='CompetitionDistance')
plt.title('Outlier in CompetitionDistance Column',color='red')
plt.ylabel('CompetitionDistance',color='red')
plt.show()

# %% [markdown]
# # 4. Upload the given dataset "sample_csv":

# %%
sample_data = pd.read_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\sample_submission.csv")

# %%
sample_data
# Out:
#           Id  Sales
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 41083  41084      0
# 41084  41085      0
# 41085  41086      0
# 41086  41087      0
# 41087  41088      0
#
# [41088 rows x 2 columns]

# %%
sample_data.shape
# Out:
# (41088, 2)

# %%
sample_data.columns
# Out:
# Index(['Id', 'Sales'], dtype='object')

# %%
sample_data.isnull().sum()
# Out:
# Id       0
# Sales    0
# dtype: int64

# %% [markdown]
# # Preprocessing:

# %%
train_data["Date"]=pd.to_datetime(train_data["Date"])
test_data["Date"]=pd.to_datetime(test_data["Date"])

# %%
#find the date part of the DatetimeIndex object.
def holiday(x):
    if x in ['a','b','c']:
        return 1
    return 0
    
def day_month_year(df, col):
    try:
        df['Day'] = pd.DatetimeIndex(df[col]).day
        df['Month'] = pd.DatetimeIndex(df[col]).month
        df['Year'] = pd.DatetimeIndex(df[col]).year
    except KeyError:
        print("Unknown Column Index")
    
train_data['Holiday'] = train_data['StateHoliday'].apply(holiday)
test_data['Holiday'] = test_data['StateHoliday'].apply(holiday)
train_data['Holiday'] = train_data['Holiday'] | train_data['SchoolHoliday']
test_data['Holiday'] = test_data['Holiday'] | test_data['SchoolHoliday']
day_month_year(train_data, 'Date') 
day_month_year(test_data, 'Date')

# %%
train_data.describe()
# Out:
#                Store      DayOfWeek                           Date  \
# count  968510.000000  968510.000000                         968510
# mean      557.325200       4.041424  2014-04-10 10:09:20.159419648
# min         1.000000       1.000000            2013-01-01 00:00:00
# 25%       276.000000       2.000000            2013-08-15 00:00:00
# 50%       558.000000       4.000000            2014-04-01 00:00:00
# 75%       841.000000       6.000000            2014-12-12 00:00:00
# max      1115.000000       7.000000            2015-07-31 00:00:00
# std       323.805198       1.993694                            NaN
#
#                Sales      Customers           Open          Promo  \
# count  968510.000000  968510.000000  968510.000000  968510.000000
# mean     5325.925106     570.167850       0.821564       0.369799
# min         0.000000       0.000000       0.000000       0.000000
# 25%      3582.000000     390.000000       1.000000       0.000000
# 50%      5575.000000     592.000000       1.000000       0.000000
# 75%      7502.000000     796.000000       1.000000       1.000000
# max     13522.000000    1484.000000       1.000000       1.000000
# std      3260.025230     350.110501       0.382880       0.482750
#
#        SchoolHoliday        Holiday           Day          Month  \
# count  968510.000000  968510.000000  968510.00000  968510.000000
# mean        0.176683       0.192540      15.71468       5.817767
# min         0.000000       0.000000       1.00000       1.000000
# 25%         0.000000       0.000000       8.00000       3.000000
# 50%         0.000000       0.000000      16.00000       6.000000
# 75%         0.000000       0.000000      23.00000       8.000000
# max         1.000000       1.000000      31.00000      12.000000
# std         0.381400       0.394295       8.76339       3.312826
#
#                 Year
# count  968510.000000
# mean     2013.832920
# min      2013.000000
# 25%      2013.000000
# 50%      2014.000000
# 75%      2014.000000
# max      2015.000000
# std         0.778095

# %%
test_data.describe()
# Out:
#                  Id         Store     DayOfWeek                 Date  \
# count  41088.000000  41088.000000  41088.000000                41088
# mean   20544.500000    555.899533      3.979167  2015-08-24 12:00:00
# min        1.000000      1.000000      1.000000  2015-08-01 00:00:00
# 25%    10272.750000    279.750000      2.000000  2015-08-12 18:00:00
# 50%    20544.500000    553.500000      4.000000  2015-08-24 12:00:00
# 75%    30816.250000    832.250000      6.000000  2015-09-05 06:00:00
# max    41088.000000   1115.000000      7.000000  2015-09-17 00:00:00
# std    11861.228267    320.274496      2.015481                  NaN
#
#                Open         Promo  SchoolHoliday       Holiday           Day  \
# count  41088.000000  41088.000000   41088.000000  41088.000000  41088.000000
# mean       0.854094      0.395833       0.443487      0.447868     13.520833
# min        0.000000      0.000000       0.000000      0.000000      1.000000
# 25%        1.000000      0.000000       0.000000      0.000000      6.750000
# 50%        1.000000      0.000000       0.000000      0.000000     12.500000
# 75%        1.000000      1.000000       1.000000      1.000000     19.250000
# max        1.000000      1.000000       1.000000      1.000000     31.000000
# std        0.353017      0.489035       0.496802      0.497281      8.448450
#
#               Month     Year
# count  41088.000000  41088.0
# mean       8.354167   2015.0
# min        8.000000   2015.0
# 25%        8.000000   2015.0
# 50%        8.000000   2015.0
# 75%        9.000000   2015.0
# max        9.000000   2015.0
# std        0.478266      0.0

# %% [markdown]
# ## Merging 'test.csv' and 'store.csv':

# %%
test_store_data = pd.merge(test_data, store_data, how = 'inner', on = 'Store')

# %%
test_store_data
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          4 2015-09-17   1.0      1            0
# 1          2      3          4 2015-09-17   1.0      1            0
# 2          4      8          4 2015-09-17   1.0      1            0
# 3          5      9          4 2015-09-17   1.0      1            0
# 4          6     10          4 2015-09-17   1.0      1            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 37771  41084   1111          6 2015-08-01   1.0      0            0
# 37772  41085   1112          6 2015-08-01   1.0      0            0
# 37773  41086   1113          6 2015-08-01   1.0      0            0
# 37774  41087   1114          6 2015-08-01   1.0      0            0
# 37775  41088   1115          6 2015-08-01   1.0      0            0
#
#        SchoolHoliday  Holiday  Day  ...  Year  StoreType Assortment  \
# 0                  0        0   17  ...  2015          c          a
# 1                  0        0   17  ...  2015          a          a
# 2                  0        0   17  ...  2015          a          a
# 3                  0        0   17  ...  2015          a          c
# 4                  0        0   17  ...  2015          a          a
# ...              ...      ...  ...  ...   ...        ...        ...
# 37771              0        0    1  ...  2015          a          a
# 37772              0        0    1  ...  2015          c          c
# 37773              0        0    1  ...  2015          a          c
# 37774              0        0    1  ...  2015          a          c
# 37775              1        1    1  ...  2015          d          c
#
#       CompetitionDistance  CompetitionOpenSinceMonth  \
# 0                  1270.0                        9.0
# 1                 14130.0                       12.0
# 2                  7520.0                       10.0
# 3                  2030.0                        8.0
# 4                  3160.0                        9.0
# ...                   ...                        ...
# 37771              1900.0                        6.0
# 37772              1880.0                        4.0
# 37773              9260.0                        8.0
# 37774               870.0                        8.0
# 37775              5350.0                        8.0
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                        2008.0       0             22.0           2012.0
# 1                        2006.0       1             14.0           2011.0
# 2                        2014.0       0             22.0           2012.0
# 3                        2000.0       0             22.0           2012.0
# 4                        2009.0       0             22.0           2012.0
# ...                         ...     ...              ...              ...
# 37771                    2014.0       1             31.0           2013.0
# 37772                    2006.0       0             22.0           2012.0
# 37773                    2010.0       0             22.0           2012.0
# 37774                    2010.0       0             22.0           2012.0
# 37775                    2010.0       1             22.0           2012.0
#
#           PromoInterval
# 0               Unknown
# 1       Jan,Apr,Jul,Oct
# 2               Unknown
# 3               Unknown
# 4               Unknown
# ...                 ...
# 37771   Jan,Apr,Jul,Oct
# 37772           Unknown
# 37773           Unknown
# 37774           Unknown
# 37775  Mar,Jun,Sept,Dec
#
# [37776 rows x 21 columns]

# %%
test_store_data.shape
# Out:
# (37776, 21)

# %%
test_store_data.columns
# Out:
# Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday', 'Holiday', 'Day', 'Month', 'Year', 'StoreType',
#        'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
test_store_data.describe()
# Out:
#                  Id         Store     DayOfWeek                 Date  \
# count  37776.000000  37776.000000  37776.000000                37776
# mean   20550.035578    563.110546      3.979167  2015-08-24 12:00:00
# min        1.000000      1.000000      1.000000  2015-08-01 00:00:00
# 25%    10272.750000    294.000000      2.000000  2015-08-12 18:00:00
# 50%    20544.500000    563.000000      4.000000  2015-08-24 12:00:00
# 75%    30816.250000    845.000000      6.000000  2015-09-05 06:00:00
# max    41088.000000   1115.000000      7.000000  2015-09-17 00:00:00
# std    11861.230105    319.633319      2.015483                  NaN
#
#                Open         Promo  SchoolHoliday       Holiday           Day  \
# count  37776.000000  37776.000000   37776.000000  37776.000000  37776.000000
# mean       0.852552      0.395833       0.442133      0.446527     13.520833
# min        0.000000      0.000000       0.000000      0.000000      1.000000
# 25%        1.000000      0.000000       0.000000      0.000000      6.750000
# 50%        1.000000      0.000000       0.000000      0.000000     12.500000
# 75%        1.000000      1.000000       1.000000      1.000000     19.250000
# max        1.000000      1.000000       1.000000      1.000000     31.000000
# std        0.354557      0.489035       0.496647      0.497139      8.448459
#
#               Month     Year  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  37776.000000  37776.0         37776.000000               37776.000000
# mean       8.354167   2015.0          3435.438374                   7.381194
# min        8.000000   2015.0            20.000000                   1.000000
# 25%        8.000000   2015.0           630.000000                   6.000000
# 50%        8.000000   2015.0          2180.000000                   8.000000
# 75%        9.000000   2015.0          5000.000000                   9.000000
# max        9.000000   2015.0         15770.000000                  12.000000
# std        0.478266      0.0          3644.230815                   2.547086
#
#        CompetitionOpenSinceYear        Promo2  Promo2SinceWeek  \
# count              37776.000000  37776.000000     37776.000000
# mean                2009.115629      0.598475        23.536213
# min                 1900.000000      0.000000         1.000000
# 25%                 2008.000000      0.000000        18.000000
# 50%                 2010.000000      1.000000        22.000000
# 75%                 2011.000000      1.000000        31.000000
# max                 2015.000000      1.000000        49.000000
# std                    5.634927      0.490213        11.072607
#
#        Promo2SinceYear
# count     37776.000000
# mean       2011.909784
# min        2009.000000
# 25%        2011.000000
# 50%        2012.000000
# 75%        2013.000000
# max        2015.000000
# std           1.300293

# %% [markdown]
# ## Merging 'train.csv' and 'store.csv':

# %%
train_store_data = pd.merge(train_data, store_data, how = 'inner', on = 'Store')

# %%
train_store_data
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0           1          5 2015-07-31   5263        555     1      1
# 1           2          5 2015-07-31   6064        625     1      1
# 2           3          5 2015-07-31   8314        821     1      1
# 3           6          5 2015-07-31   5651        589     1      1
# 4           8          5 2015-07-31   8492        833     1      1
# ...       ...        ...        ...    ...        ...   ...    ...
# 872008   1111          2 2013-01-01      0          0     0      0
# 872009   1112          2 2013-01-01      0          0     0      0
# 872010   1113          2 2013-01-01      0          0     0      0
# 872011   1114          2 2013-01-01      0          0     0      0
# 872012   1115          2 2013-01-01      0          0     0      0
#
#        StateHoliday  SchoolHoliday  Holiday  ...  Year  StoreType  Assortment  \
# 0                 0              1        1  ...  2015          c           a
# 1                 0              1        1  ...  2015          a           a
# 2                 0              1        1  ...  2015          a           a
# 3                 0              1        1  ...  2015          a           a
# 4                 0              1        1  ...  2015          a           a
# ...             ...            ...      ...  ...   ...        ...         ...
# 872008            a              1        1  ...  2013          a           a
# 872009            a              1        1  ...  2013          c           c
# 872010            a              1        1  ...  2013          a           c
# 872011            a              1        1  ...  2013          a           c
# 872012            a              1        1  ...  2013          d           c
#
#        CompetitionDistance CompetitionOpenSinceMonth  \
# 0                   1270.0                       9.0
# 1                    570.0                      11.0
# 2                  14130.0                      12.0
# 3                    310.0                      12.0
# 4                   7520.0                      10.0
# ...                    ...                       ...
# 872008              1900.0                       6.0
# 872009              1880.0                       4.0
# 872010              9260.0                       8.0
# 872011               870.0                       8.0
# 872012              5350.0                       8.0
#
#         CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                         2008.0       0             22.0           2012.0
# 1                         2007.0       1             13.0           2010.0
# 2                         2006.0       1             14.0           2011.0
# 3                         2013.0       0             22.0           2012.0
# 4                         2014.0       0             22.0           2012.0
# ...                          ...     ...              ...              ...
# 872008                    2014.0       1             31.0           2013.0
# 872009                    2006.0       0             22.0           2012.0
# 872010                    2010.0       0             22.0           2012.0
# 872011                    2010.0       0             22.0           2012.0
# 872012                    2010.0       1             22.0           2012.0
#
#            PromoInterval
# 0                Unknown
# 1        Jan,Apr,Jul,Oct
# 2        Jan,Apr,Jul,Oct
# 3                Unknown
# 4                Unknown
# ...                  ...
# 872008   Jan,Apr,Jul,Oct
# 872009           Unknown
# 872010           Unknown
# 872011           Unknown
# 872012  Mar,Jun,Sept,Dec
#
# [872013 rows x 22 columns]

# %%
train_store_data.shape
# Out:
# (872013, 22)

# %%
train_store_data.describe()
# Out:
#                Store      DayOfWeek                           Date  \
# count  872013.000000  872013.000000                         872013
# mean      557.526921       4.041140  2014-04-10 08:11:36.738237184
# min         1.000000       1.000000            2013-01-01 00:00:00
# 25%       278.000000       2.000000            2013-08-15 00:00:00
# 50%       555.000000       4.000000            2014-04-01 00:00:00
# 75%       843.000000       6.000000            2014-12-12 00:00:00
# max      1115.000000       7.000000            2015-07-31 00:00:00
# std       323.949488       1.994343                            NaN
#
#                Sales      Customers           Open          Promo  \
# count  872013.000000  872013.000000  872013.000000  872013.000000
# mean     5311.881787     572.407872       0.820303       0.369829
# min         0.000000       0.000000       0.000000       0.000000
# 25%      3586.000000     391.000000       1.000000       0.000000
# 50%      5562.000000     592.000000       1.000000       0.000000
# 75%      7480.000000     801.000000       1.000000       1.000000
# max     13522.000000    1484.000000       1.000000       1.000000
# std      3252.307977     352.786622       0.383935       0.482759
#
#        SchoolHoliday        Holiday            Day          Month  \
# count  872013.000000  872013.000000  872013.000000  872013.000000
# mean        0.177125       0.193003      15.714575       5.816128
# min         0.000000       0.000000       1.000000       1.000000
# 25%         0.000000       0.000000       8.000000       3.000000
# 50%         0.000000       0.000000      16.000000       6.000000
# 75%         0.000000       0.000000      23.000000       8.000000
# max         1.000000       1.000000      31.000000      12.000000
# std         0.381774       0.394655       8.763229       3.312793
#
#                 Year  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  872013.000000        872013.000000              872013.000000
# mean     2013.832833          3501.810168                   7.512563
# min      2013.000000            20.000000                   1.000000
# 25%      2013.000000           650.000000                   6.000000
# 50%      2014.000000          2100.000000                   8.000000
# 75%      2014.000000          4880.000000                   9.000000
# max      2015.000000         15770.000000                  12.000000
# std         0.778317          3776.531892                   2.685665
#
#        CompetitionOpenSinceYear         Promo2  Promo2SinceWeek  \
# count             872013.000000  872013.000000    872013.000000
# mean                2009.088705       0.531950        22.649881
# min                 1900.000000       0.000000         1.000000
# 25%                 2008.000000       0.000000        18.000000
# 50%                 2010.000000       1.000000        22.000000
# 75%                 2011.000000       1.000000        22.000000
# max                 2015.000000       1.000000        50.000000
# std                    5.146021       0.498978        10.355083
#
#        Promo2SinceYear
# count    872013.000000
# mean       2011.890884
# min        2009.000000
# 25%        2012.000000
# 50%        2012.000000
# 75%        2012.000000
# max        2015.000000
# std           1.200925

# %% [markdown]
# # Exploratory Data Analysis (EDA):

# %% [markdown]
# ## 1.1- Distribution of Promotions in Training and Test Sets:

# %%
sns.countplot(x='Promo', data=test_data)
plt.title('Promo Distribution in Test Set')
plt.show()

# %%
sns.countplot(x='Promo', data=train_data)
plt.title('Promo Distribution in Training Set')
plt.show()

# %% [markdown]
# ## 1.2- Sales Behavior Before, During, and After Holidays:

# %% [markdown]
# ## Create a feature to indicate whether the day is during holiday

# %%
train_store_data['HolidayPeriod'] = 'Regular'
train_store_data.loc[train_store_data['StateHoliday'] != '0', 'HolidayPeriod'] = 'During Holiday'

# %% [markdown]
# ## Create a feature to indicate whether the day is before holiday

# %%
train_store_data.loc[(train_store_data['StateHoliday'] == '0') & 
                     (train_store_data['Date'].dt.dayofweek == 6) & 
                     (train_store_data['Date'].shift(-1).dt.dayofweek == 0), 'HolidayPeriod'] = 'Before Holiday'

# %% [markdown]
# ## Create a feature to indicate whether the day is after holiday

# %%
train_store_data.loc[(train_store_data['StateHoliday'] == '0') & 
                     (train_store_data['Date'].dt.dayofweek == 0) & 
                     (train_store_data['Date'].shift(1).dt.dayofweek == 6), 'HolidayPeriod'] = 'After Holiday'

# %% [markdown]
# ## Plot sales behavior during different holidays periods:

# %%
sns.boxplot(x='HolidayPeriod', y='Sales', data=train_store_data)
plt.title('Sales Behavior Before, During, and After Holidays')
plt.show()

# %% [markdown]
# ## 1.3- Seasonal Purchase Behaviors (Christmas, Easter, etc.):

# %%
# Extract month and day for easier seasonal analysis
train_store_data['Month'] = train_store_data['Date'].dt.month
train_store_data['Day'] = train_store_data['Date'].dt.day

# %%
# Plot sales by month to identify seasonal patterns
monthly_sales = train_store_data.groupby('Month')['Sales'].sum().reset_index()
sns.lineplot(x='Month', y='Sales', data=monthly_sales)
plt.title('Monthly Sales Patterns')
plt.show()

# %% [markdown]
# ## 1.4- Correlation Between Sales and Number of Customers:

# %%
sns.scatterplot(x='Customers', y='Sales', data=train_store_data)
plt.title('Correlation Between Sales and Number of Customers')
plt.show()

# %% [markdown]
# ## 1.5- Effect of Promos on Sales:

# %%
sns.boxplot(x='Promo', y='Sales', data=train_store_data)
plt.title('Effect of Promo on Sales')
plt.show()

# %%
# Correlation between promo, Customers and sales
train_store_data[['Promo', 'Customers','Sales']].corr()
# Out:
#               Promo  Customers     Sales
# Promo      1.000000   0.366715  0.478154
# Customers  0.366715   1.000000  0.911452
# Sales      0.478154   0.911452  1.000000

# %% [markdown]
# ## 1.6- Deployment of Promos in Stores:

# %%
# Analyze the effect of promo on customers
sns.boxplot(x='Promo', y='Customers', data=train_store_data)
plt.title('Effect of Promo on Customer Count')
plt.show()

# %%
# Check store-wise promo effect
store_promo_effect = train_store_data.groupby('Store')[['Promo', 'Sales']].mean().reset_index()
sns.scatterplot(x='Promo', y='Sales', data=store_promo_effect)
plt.title('Store-wise Promo Effect on Sales')
plt.show()

# %% [markdown]
# ## 1.7- Customer Behavior During Store Open and Closing Times:

# %%
# Analyze sales patterns by day of the week
sns.boxplot(x='DayOfWeek', y='Sales', data=train_store_data)
plt.title('Sales Patterns by Day of the Week')
plt.show()

# %% [markdown]
# ## 1.8- Weekday Open Stores and Weekend Sales:

# %%
# Identify stores that are open on all weekdays
weekday_data = train_store_data[train_store_data['DayOfWeek'].isin([1, 2, 3, 4, 5])]
weekday_open_stores = train_store_data.groupby('Store')['Open'].sum().reset_index()
weekday_open_stores = weekday_open_stores[weekday_open_stores == 5].index.tolist()

# %%
# Compare weekend sales for these stores
weekend_sales = train_store_data[(train_store_data['Store'].isin(weekday_open_stores)) & (train_store_data['DayOfWeek'] >= 6)]
sns.boxplot(x='DayOfWeek', y='Sales', data=weekend_sales)
plt.title('Weekend Sales for Stores Open on All Weekdays')
plt.show()

# %% [markdown]
# ## 1.9- Effect of Assortment Type on Sales:

# %%
# Analyze the effect of assortment type on sales
sns.boxplot(x='Assortment', y='Sales', data=train_store_data)
plt.title('Effect of Assortment Type on Sales')
plt.show()

# %% [markdown]
# ## 1.10- Impact of Competitor Distance on Sales:

# %%
# Scatter plot of CompetitionDistance vs Sales
plt.figure(figsize=(12, 6))
sns.scatterplot(x='CompetitionDistance', y='Sales', data=train_store_data)
plt.title('Effect of Competitor Distance on Sales')
plt.xlabel('Competition Distance')
plt.ylabel('Sales')
plt.show()

# %%
# Assume city center stores have a high density of competitors and a short distance
city_center_stores = train_store_data[train_store_data['CompetitionDistance'] < 1000]

# %%
# Scatter plot for city center stores
plt.figure(figsize=(12, 6))
sns.scatterplot(x='CompetitionDistance', y='Sales', data=city_center_stores)
plt.title('Effect of Competitor Distance on Sales in City Centers')
plt.xlabel('Competition Distance')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## 1.11- Effect of New Competitors:

# %%
# Identify stores with NA initially in CompetitionDistance and later values
initial_na_competition = train_store_data[train_store_data['CompetitionDistance'].isna()]
later_competition = train_store_data[train_store_data['CompetitionDistance'].notna()]

# %%
# Analyze the sales before and after the competition opens
initial_sales = initial_na_competition.groupby('Store')['Sales'].mean()
later_sales = later_competition.groupby('Store')['Sales'].mean()

# %%
sales_effect = later_sales - initial_sales
print(sales_effect)
# Out:
# Store
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 6      NaN
#         ..
# 1111   NaN
# 1112   NaN
# 1113   NaN
# 1114   NaN
# 1115   NaN
# Name: Sales, Length: 1005, dtype: float64

# %%
sns.boxplot(x='Store', y='Sales', data=train_store_data)
plt.title('sales before and after the competition opens')
plt.show()

# %% [markdown]
# # Achievement: Convert and save the train,test & store cleaned data sets

# %%
train_data.to_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\cleaned_train_data.csv",index=False)
test_data.to_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\cleaned_test_data.csv",index=False)
store_data.to_csv(r"C:\Users\LENOVO\Downloads\DC Project\P6\cleaned_store_data.csv",index=False)
